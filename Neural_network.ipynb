# %% [markdown]
# # Import necessary modules

# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import plot_tree
sb.set()

from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import mean_squared_error, r2_score

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.models import Sequential
from keras.layers import Dense, Dropout
from tensorflow.keras.metrics import Precision, Recall

# %% [markdown]
# # Import cleaned file

# %%
laptop_data_clean = pd.read_csv('./laptop_data_clean.csv', encoding='latin-1')
laptop_data_clean.head()
# Out:
#   Company      Product   TypeName  Inches ScreenResolution            Cpu  \
# 0   Apple  MacBook Pro  Ultrabook    13.3        2560x1600  Intel Core i5
# 1   Apple  Macbook Air  Ultrabook    13.3         1440x900  Intel Core i5
# 2      HP       250 G6   Notebook    15.6        1920x1080  Intel Core i5
# 3   Apple  MacBook Pro  Ultrabook    15.4        2880x1800  Intel Core i7
# 4   Apple  MacBook Pro  Ultrabook    13.3        2560x1600  Intel Core i5
#
#    Ram               Memory                           Gpu  OpSys  Weight  \
# 0    8            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1    8  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2    8            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3   16            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4    8            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#    Price_sgd
# 0    2103.31
# 1    1411.34
# 2     902.75
# 3    3983.80
# 4    2831.65

# %%
## from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
laptop_data_clean['Company'] = le.fit_transform(laptop_data_clean['Company'])
laptop_data_clean['Product'] = le.fit_transform(laptop_data_clean['Product'])
laptop_data_clean['TypeName'] = le.fit_transform(laptop_data_clean['TypeName'])
laptop_data_clean['ScreenResolution'] = le.fit_transform(laptop_data_clean['ScreenResolution'])
laptop_data_clean['Memory'] = le.fit_transform(laptop_data_clean['Memory'])
laptop_data_clean['Cpu'] = le.fit_transform(laptop_data_clean['Cpu'])
laptop_data_clean['Gpu'] = le.fit_transform(laptop_data_clean['Gpu'])
laptop_data_clean['OpSys'] = le.fit_transform(laptop_data_clean['OpSys'])
laptop_data_clean
# Out:
#       Company  Product  TypeName  Inches  ScreenResolution  Cpu  Ram  Memory  \
# 0           1      297         4    13.3                10    2    8       4
# 1           1      298         4    13.3                 1    2    8       2
# 2           7       50         3    15.6                 3    2    8      16
# 3           1      297         4    15.4                12    3   16      29
# 4           1      297         4    13.3                10    2    8      16
# ...       ...      ...       ...     ...               ...  ...  ...     ...
# 1298       10      555         0    14.0                 3    3    4       4
# 1299       10      563         0    13.3                13    3   16      29
# 1300       10      193         3    14.0                 0    4    2      35
# 1301        7        2         3    15.6                 0    3    6      10
# 1302        2      543         3    15.6                 0    4    4      26
#
#       Gpu  OpSys  Weight  Price_sgd
# 0      58      8    1.37    2103.31
# 1      51      8    1.34    1411.34
# 2      53      4    1.86     902.75
# 3       9      8    1.83    3983.80
# 4      59      8    1.37    2831.65
# ...   ...    ...     ...        ...
# 1298   47      5    1.80    1001.66
# 1299   47      5    1.30    2353.43
# 1300   40      5    1.50     359.53
# 1301   21      5    2.19    1199.48
# 1302   40      5    2.20     579.33
#
# [1303 rows x 12 columns]

# %% [markdown]
# # Helper functions

# %%
def visualize_training_history(history):
    f, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 6))
    f.suptitle('Training History', fontweight='bold', fontsize='x-large')
    
    ax.plot(history.history['loss'], label='Loss (training data)')
    ax.set_title('Loss History')
    ax.set(ylabel='Loss', xlabel='Number of Epochs')
    ax.legend(loc="upper right")
    
    # plt.show()

# %%
def standardize(X_train, X_test):
    scaler = StandardScaler()
    X_train_std = scaler.fit_transform(X_train)
    X_test_std = scaler.transform(X_test)
    
    return X_train_std, X_test_std

# %% [markdown]
# # Model training

# %% [markdown]
# ### Data preparation
# For the predictors we used the 4 attributes with the highest correlation and for the response we set it as the response. The dataset is split 80:20 for the training and test sets respectively.

# %%
# Prepare the features (X) and target variable (y)
X = laptop_data_clean[['Ram', 'ScreenResolution', 'OpSys', 'Gpu' ]]
y = laptop_data_clean['Price_sgd']
# y = np.log(laptop_data_clean['Price_sgd'])

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# X_train, X_test = standardize(X_train, X_test)

# %% [markdown]
# ### Build neural network model
# Using the Keras library, we build a neural network model with two hidden layers, one with 32 neurons and the other with 16 neurons. The hidden layers use the ReLu (Rectified Linear Unit) activation layer.
#
# We compile the model using the Adam optimizer and mean squared error as the loss function. Then, we train the model for 100 epochs with a batch size of 32.

# %%
training_histories ={}

# Build the neural network model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(32, activation='relu', input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(1)  # Output layer with one neuron (for regression)
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')
# model.compile(loss='mean_squared_error', optimizer='adam', 
#                   metrics=['accuracy', Precision(name='precision'), Recall(name='recall')])

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32, verbose=1)

# Evaluate the model
loss = model.evaluate(X_test, y_test)
print("Mean Squared Error on Test Data:", loss)

# Save training history
training_histories['Original'] = history
# Out:
# Epoch 1/100
# C:\Users\cheng\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4286983.5000
# Epoch 2/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step - loss: 4371787.5000
# Epoch 3/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step - loss: 4204282.0000
# Epoch 4/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - loss: 3996000.7500
# Epoch 5/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - loss: 3710292.5000
# Epoch 6/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step - loss: 3662916.2500
# Epoch 7/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - loss: 3248391.0000
# Epoch 8/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step - loss: 2718907.7500
# Epoch 9/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step - loss: 2379966.2500
# Epoch 10/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - loss: 1793538.2500
# Epoch 11/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - loss: 1522631.1250
# Epoch 12/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step - loss: 929404.0625
# Epoch 13/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 832429.6250
# Epoch 14/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step - loss: 847151.6250
# Epoch 15/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - loss: 748093.1875
# Epoch 16/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step - loss: 679459.9375
# Epoch 17/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step - loss: 707696.5625
# Epoch 18/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - loss: 729775.0625
# Epoch 19/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - loss: 799408.5625
# Epoch 20/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - loss: 743401.1875
# Epoch 21/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - loss: 719359.8750
# Epoch 22/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 737204.0625
# Epoch 23/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 674171.8750
# Epoch 24/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - loss: 644709.6875
# Epoch 25/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - loss: 650117.4375
# Epoch 26/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step - loss: 656808.8750
# Epoch 27/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 604469.3750
# Epoch 28/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 705049.6875
# Epoch 29/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - loss: 622763.5625
# Epoch 30/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step - loss: 596093.2500
# Epoch 31/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step - loss: 605540.1250
# Epoch 32/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 568149.0625
# Epoch 33/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 576080.2500
# Epoch 34/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 627345.3125
# Epoch 35/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 586189.5000
# Epoch 36/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 518798.6250
# Epoch 37/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - loss: 585271.5625
# Epoch 38/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - loss: 511689.2812
# Epoch 39/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step - loss: 501862.5000
# Epoch 40/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step - loss: 535622.5000
# Epoch 41/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - loss: 576835.1250
# Epoch 42/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 528281.9375
# Epoch 43/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 504331.9062
# Epoch 44/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - loss: 528298.6875
# Epoch 45/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - loss: 532027.0625
# Epoch 46/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 523237.1562
# Epoch 47/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 459481.0938
# Epoch 48/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 517170.2812
# Epoch 49/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 529861.5625
# Epoch 50/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 540471.0000
# Epoch 51/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 473453.9688
# Epoch 52/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 511615.5625
# Epoch 53/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 487476.3125
# Epoch 54/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 519488.9062
# Epoch 55/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 481976.8438
# Epoch 56/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 500760.4062
# Epoch 57/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step - loss: 508179.7500
# Epoch 58/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 531677.9375
# Epoch 59/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 496372.1875
# Epoch 60/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 454920.4062
# Epoch 61/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 444705.7812
# Epoch 62/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 506729.2812
# Epoch 63/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 466125.4375
# Epoch 64/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 558571.4375
# Epoch 65/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 501820.0312
# Epoch 66/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 461855.7500
# Epoch 67/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 452760.9375
# Epoch 68/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 499692.9375
# Epoch 69/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 489949.8750
# Epoch 70/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - loss: 504480.2812
# Epoch 71/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - loss: 488127.3438
# Epoch 72/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 479876.6250
# Epoch 73/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - loss: 429118.1562
# Epoch 74/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - loss: 493890.6875
# Epoch 75/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - loss: 554405.2500
# Epoch 76/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 512635.9062
# Epoch 77/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 444861.4375
# Epoch 78/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 476632.0000
# Epoch 79/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step - loss: 479237.4688
# Epoch 80/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step - loss: 440707.1250
# Epoch 81/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step - loss: 465691.2812
# Epoch 82/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - loss: 451649.6250
# Epoch 83/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - loss: 495731.8125
# Epoch 84/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - loss: 516996.7500
# Epoch 85/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 543758.8750
# Epoch 86/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - loss: 450811.1562
# Epoch 87/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step - loss: 469915.6875
# Epoch 88/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 452443.7500
# Epoch 89/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 546002.3750
# Epoch 90/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 500144.2500
# Epoch 91/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 493921.1562
# Epoch 92/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 443992.1250
# Epoch 93/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 437532.4688
# Epoch 94/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 507171.2812
# Epoch 95/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 453703.4688
# Epoch 96/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 489379.5000
# Epoch 97/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - loss: 476198.5625
# Epoch 98/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - loss: 477107.8750
# Epoch 99/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 477701.7188
# Epoch 100/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 490354.7188
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 375727.4375
# Mean Squared Error on Test Data: 376494.40625

# %%
visualize_training_history(history)

# %%
predictions = model.predict(X_test)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %% [markdown]
# ### Model performance
# Using the graph below which compares the predicted price and the actual price, we can see that the model is not the most accurate. This is also reflected in the high MSE values.

# %%
# Plot actual vs predicted values
plt.figure(figsize=(14, 5))
# plt.plot(np.exp(y_test.values), label='Actual Price', color='green')
# plt.plot(np.exp(predictions), label='Predicted Price', color='blue')
plt.plot(y_test.values, label='Actual Price', color='green')
plt.plot(predictions, label='Predicted Price', color='blue')
plt.xlabel('Index')
plt.ylabel('Price')
plt.title('Predicted vs Actual Price')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Testing model predictions
# Using the neural network model, we tried predicting the laptop prices given the 4 chosen attributes. The prices predicted were a few hundred dollars off from the actual prices.

# %%
def test_model_predictions():
    # Extract the first few rows for testing
    test_data = laptop_data_clean.head()
    
    # Iterate over the test data and make predictions
    for index, row in test_data.iterrows():
        ram = row['Ram']
        screen_resolution = row['ScreenResolution']
        operating_system = row['OpSys']
        gpu = row['Gpu']

        # print(ram)
        # print(screen_resolution)
        # print(operating_system)
        # print(gpu)
        
        # Prepare input data
        input_data = np.array([[ram, screen_resolution, operating_system, gpu]])
        
        # Make prediction
        prediction = model.predict(input_data)[0][0]
        
        # Find actual price based on input parameters
        actual_price = row['Price_sgd']
        
        print("Test Case - Laptop ID:", index)
        # print("Predicted Price: $", round(np.exp(prediction), 2))
        print("Predicted Price: $", round(prediction, 2))
        print("Actual Price: $", round(actual_price, 2))
        print("="*50)

# Example usage:
test_model_predictions()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Test Case - Laptop ID: 0
# Predicted Price: $ 2297.43
# Actual Price: $ 2103.31
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Test Case - Laptop ID: 1
# Predicted Price: $ 1774.74
# Actual Price: $ 1411.34
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Test Case - Laptop ID: 2
# Predicted Price: $ 1681.75
# Actual Price: $ 902.75
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Test Case - Laptop ID: 3
# Predicted Price: $ 2970.79
# Actual Price: $ 3983.8
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Test Case - Laptop ID: 4
# Predicted Price: $ 2302.93
# Actual Price: $ 2831.65
# ==================================================

# %% [markdown]
# ### Improving Model Performance
# Since the neural network model did not perform exceptionally well and the MSE was very high, we tried to improve the model in various methods.
#
# **1. Normalising data**
# We tried taking the logarithm of the attribute data to help in normalizing the distribution of skewed data and mitigate the effect of outliers.

# %%
# Prepare the features (X) and target variable (y)
X = laptop_data_clean[['Ram', 'ScreenResolution', 'OpSys', 'Gpu' ]]
# y = laptop_data_clean['Price_sgd']
y = np.log(laptop_data_clean['Price_sgd'])

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# X_train, X_test = standardize(X_train, X_test)

# %% [markdown]
# When running the same model again with the normalised data, we find that the MSE is much smaller.

# %%
training_histories ={}

# Build the neural network model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(32, activation='relu', input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(1)  # Output layer with one neuron (for regression)
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')
# model.compile(loss='mean_squared_error', optimizer='adam', 
#                   metrics=['accuracy', Precision(name='precision'), Recall(name='recall')])

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32, verbose=1)

# Evaluate the model
loss = model.evaluate(X_test, y_test)
print("Mean Squared Error on Test Data:", loss)

# Save training history
training_histories['Original'] = history

predictions = model.predict(X_test)
# Out:
# Epoch 1/100
# C:\Users\cheng\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 23.5645
# Epoch 2/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5407
# Epoch 3/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.4541
# Epoch 4/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.3111
# Epoch 5/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - loss: 3.1722
# Epoch 6/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - loss: 2.3629
# Epoch 7/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step - loss: 1.8993
# Epoch 8/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step - loss: 1.2322
# Epoch 9/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - loss: 1.1036
# Epoch 10/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step - loss: 0.9570
# Epoch 11/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - loss: 0.8997
# Epoch 12/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - loss: 0.7962
# Epoch 13/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - loss: 0.8700
# Epoch 14/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - loss: 0.7083
# Epoch 15/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7157
# Epoch 16/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - loss: 0.6895
# Epoch 17/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7129
# Epoch 18/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7013
# Epoch 19/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step - loss: 0.6352
# Epoch 20/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - loss: 0.6318
# Epoch 21/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step - loss: 0.7468
# Epoch 22/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - loss: 0.6493
# Epoch 23/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - loss: 0.5682
# Epoch 24/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5817
# Epoch 25/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6309
# Epoch 26/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - loss: 0.6392
# Epoch 27/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step - loss: 0.4706
# Epoch 28/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5563
# Epoch 29/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - loss: 0.4923
# Epoch 30/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.5731
# Epoch 31/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step - loss: 0.4370
# Epoch 32/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - loss: 0.4728
# Epoch 33/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - loss: 0.4994
# Epoch 34/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5000
# Epoch 35/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - loss: 0.5442
# Epoch 36/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - loss: 0.3958
# Epoch 37/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4572
# Epoch 38/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4419
# Epoch 39/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 817us/step - loss: 0.3965
# Epoch 40/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - loss: 0.4113
# Epoch 41/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step - loss: 0.3796
# Epoch 42/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - loss: 0.3456
# Epoch 43/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3502
# Epoch 44/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - loss: 0.3183
# Epoch 45/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3545
# Epoch 46/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3817
# Epoch 47/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3203
# Epoch 48/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3417
# Epoch 49/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3118
# Epoch 50/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2885
# Epoch 51/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2747
# Epoch 52/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - loss: 0.2819
# Epoch 53/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step - loss: 0.2973
# Epoch 54/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2491
# Epoch 55/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2509
# Epoch 56/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2498
# Epoch 57/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2611
# Epoch 58/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2434
# Epoch 59/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2422
# Epoch 60/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2391
# Epoch 61/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2289
# Epoch 62/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2226
# Epoch 63/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2027
# Epoch 64/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2289
# Epoch 65/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - loss: 0.2186
# Epoch 66/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step - loss: 0.2354
# Epoch 67/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1836
# Epoch 68/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1971
# Epoch 69/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2020
# Epoch 70/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1877
# Epoch 71/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1704
# Epoch 72/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1892
# Epoch 73/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1775
# Epoch 74/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - loss: 0.1926
# Epoch 75/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step - loss: 0.1858
# Epoch 76/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - loss: 0.1879
# Epoch 77/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1754
# Epoch 78/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - loss: 0.1682
# Epoch 79/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - loss: 0.1592
# Epoch 80/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - loss: 0.1950
# Epoch 81/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1493
# Epoch 82/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - loss: 0.1464
# Epoch 83/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1695
# Epoch 84/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1547
# Epoch 85/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1610
# Epoch 86/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - loss: 0.1507
# Epoch 87/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1619
# Epoch 88/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step - loss: 0.1480
# Epoch 89/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step - loss: 0.1822
# Epoch 90/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step - loss: 0.1873
# Epoch 91/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1455
# Epoch 92/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step - loss: 0.1616
# Epoch 93/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1508
# Epoch 94/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1608
# Epoch 95/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1450
# Epoch 96/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1626
# Epoch 97/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1424
# Epoch 98/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1461
# Epoch 99/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step - loss: 0.1496
# Epoch 100/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - loss: 0.1616
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1826
# Mean Squared Error on Test Data: 0.16005775332450867
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %% [markdown]
# ### Testing model performance with normalised data
# When plotting the graph of the actual and predicted prices, we noticed that although the MSE is much better, the graph doesn't really show a significant improvement. It does appear to be slightly more accurate than the previous one but there are still several predictions that are off by a large margin.

# %%
# Plot actual vs predicted values
plt.figure(figsize=(10, 5))
# plt.plot(np.exp(y_test.values), label='Actual Price', color='green')
# plt.plot(np.exp(predictions), label='Predicted Price', color='blue')
plt.plot(y_test.values, label='Actual Price', color='green')
plt.plot(predictions, label='Predicted Price', color='blue')
plt.xlabel('Index')
plt.ylabel('Price')
plt.title('Predicted vs Actual Price')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Testing model predictions with normalised data
# Using the neural network model with normalised data, we tried predicting the laptop prices given the 4 chosen attributes. Like previously the prices predicted were a few hundred dollars off from the actual prices which does not show a significant improvement despite the lower MSE.

# %%
def test_model_predictions_normalised():
    # Extract the first few rows for testing
    test_data = laptop_data_clean.head()
    
    # Iterate over the test data and make predictions
    for index, row in test_data.iterrows():
        ram = row['Ram']
        screen_resolution = row['ScreenResolution']
        operating_system = row['OpSys']
        gpu = row['Gpu']

        # print(ram)
        # print(screen_resolution)
        # print(operating_system)
        # print(gpu)
        
        # Prepare input data
        input_data = np.array([[ram, screen_resolution, operating_system, gpu]])
        
        # Make prediction
        prediction = model.predict(input_data)[0][0]
        
        # Find actual price based on input parameters
        actual_price = row['Price_sgd']
        
        print("Test Case - Laptop ID:", index)
        print("Predicted Price: $", round(np.exp(prediction), 2))
        # print("Predicted Price: $", round(prediction, 2))
        print("Actual Price: $", round(actual_price, 2))
        print("="*50)

# Example usage:
test_model_predictions_normalised()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Test Case - Laptop ID: 0
# Predicted Price: $ 5075.35
# Actual Price: $ 2103.31
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Test Case - Laptop ID: 1
# Predicted Price: $ 2474.44
# Actual Price: $ 1411.34
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Test Case - Laptop ID: 2
# Predicted Price: $ 1695.84
# Actual Price: $ 902.75
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Test Case - Laptop ID: 3
# Predicted Price: $ 3708.87
# Actual Price: $ 3983.8
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Test Case - Laptop ID: 4
# Predicted Price: $ 5175.05
# Actual Price: $ 2831.65
# ==================================================

# %% [markdown]
# ## Analysis
# The outcome of both models were not as great as expected. Although we tried to tune the parameters of the neural network model such as the batch size, the epoch and the number of neurons in each layer, they did not yield a significant improvement to the MSE (from ~400k to ~0.2) and the predictions.
#
# We also tried normalising the data using the log function to normalised the data since some of the data were quite skewed (refer to data_visualization.ipynb). However, although it did reduce the MSE significantly, it did little to improve the actual predictions. In fact, the predictions were quite a bit worse than the model built without normalising because of the reverse log function that is applied to get the predicted price.
#
# Looking at the linear regression model (linear_regression.ipynb), it's MSE is also around 400 000, similar to the neural network model. Hence, we concluded that although the MSE is lower with the log function, it may also magnify the differences between small values which may amplify the impact of outliers, leading to a worse prediction.
